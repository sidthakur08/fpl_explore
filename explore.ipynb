# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
pd.set_option('max_columns',500)

# %%
if not os.path.exists("images"):
    os.mkdir("images")

# %%
outfield_data = pd.read_csv('2019-20_out.csv')
keeper_data = pd.read_csv('2019-20_gk.csv')

# %%
for i in outfield_data.columns:
    print("'%s'"%i,end=', ')
# Out:
# 'player', 'nationality', 'position', 'squad', 'age', 'birth_year', 'games', 'games_starts', 'minutes', 'goals', 'assists', 'pens_made', 'pens_att', 'cards_yellow', 'cards_red', 'goals_per90', 'assists_per90', 'goals_assists_per90', 'goals_pens_per90', 'goals_assists_pens_per90', 'xg', 'npxg', 'xa', 'xg_per90', 'xa_per90', 'xg_xa_per90', 'npxg_per90', 'npxg_xa_per90', 'minutes_90s', 'shots_total', 'shots_on_target', 'shots_free_kicks', 'shots_on_target_pct', 'shots_total_per90', 'shots_on_target_per90', 'goals_per_shot', 'goals_per_shot_on_target', 'npxg_per_shot', 'xg_net', 'npxg_net', 'passes_completed', 'passes', 'passes_pct', 'passes_total_distance', 'passes_progressive_distance', 'passes_completed_short', 'passes_short', 'passes_pct_short', 'passes_completed_medium', 'passes_medium', 'passes_pct_medium', 'passes_completed_long', 'passes_long', 'passes_pct_long', 'xa_net', 'assisted_shots', 'passes_into_final_third', 'passes_into_penalty_area', 'crosses_into_penalty_area', 'progre
# ...

# %%
for i in keeper_data.columns:
    print("'%s'"%i,end=', ')
# Out:
# 'player', 'nationality', 'position', 'squad', 'age', 'birth_year', 'games_gk', 'games_starts_gk', 'minutes_gk', 'goals_against_gk', 'goals_against_per90_gk', 'shots_on_target_against', 'saves', 'save_pct', 'wins_gk', 'draws_gk', 'losses_gk', 'clean_sheets', 'clean_sheets_pct', 'pens_att_gk', 'pens_allowed', 'pens_saved', 'pens_missed_gk', 'minutes_90s_gk', 'free_kick_goals_against_gk', 'corner_kick_goals_against_gk', 'own_goals_against_gk', 'psxg_gk', 'psnpxg_per_shot_on_target_against', 'psxg_net_gk', 'psxg_net_per90_gk', 'passes_completed_launched_gk', 'passes_launched_gk', 'passes_pct_launched_gk', 'passes_gk', 'passes_throws_gk', 'pct_passes_launched_gk', 'passes_length_avg_gk', 'goal_kicks', 'pct_goal_kicks_launched', 'goal_kick_length_avg', 'crosses_gk', 'crosses_stopped_gk', 'crosses_stopped_pct_gk', 'def_actions_outside_pen_area_gk', 'def_actions_outside_pen_area_per90_gk', 'avg_distance_def_actions_gk',

# %%
outfield_data
# Out:
#                         player nationality position            squad  age  \
# 0          Patrick van Aanholt      nl NED       DF   Crystal Palace   28
# 1                   Max Aarons     eng ENG       DF     Norwich City   19
# 2                Tammy Abraham     eng ENG       FW          Chelsea   21
# 3                    Che Adams     eng ENG       FW      Southampton   23
# 4                       Adrián      es ESP       GK        Liverpool   32
# 5                Sergio Agüero      ar ARG       FW  Manchester City   31
# 6                 Albian Ajeti      ch SUI    MF,FW         West Ham   22
# 7                   Nathan Aké      nl NED       DF      Bournemouth   24
# 8              Marc Albrighton     eng ENG    MF,DF   Leicester City   29
# 9            Toby Alderweireld      be BEL       DF        Tottenham   30
# 10      Trent Alexander-Arnold     eng ENG       DF        Liverpool   20
# 11                     Alisson      br BRA       GK        Liverpool   26
# ...

# %%
out = outfield_data.loc[:,['player','position','squad','age','games','games_starts','minutes','goals','assists',
                   'cards_yellow','cards_red','goals_per90','assists_per90','goals_assists_per90',
                   'goals_pens_per90','goals_assists_pens_per90','xg','npxg','xa','xg_per90','xa_per90',
                   'xg_xa_per90','npxg_per90','npxg_xa_per90','tackles','tackles_won','dribble_tackles_pct',
                   'pressure_regain_pct','blocked_shots','blocked_shots_saves','fouls','cards_yellow','cards_red']]
out
# Out:
#                         player position            squad  age  games  \
# 0          Patrick van Aanholt       DF   Crystal Palace   28   29.0
# 1                   Max Aarons       DF     Norwich City   19   36.0
# 2                Tammy Abraham       FW          Chelsea   21   34.0
# 3                    Che Adams       FW      Southampton   23   30.0
# 4                       Adrián       GK        Liverpool   32   11.0
# 5                Sergio Agüero       FW  Manchester City   31   24.0
# 6                 Albian Ajeti    MF,FW         West Ham   22    9.0
# 7                   Nathan Aké       DF      Bournemouth   24   29.0
# 8              Marc Albrighton    MF,DF   Leicester City   29   20.0
# 9            Toby Alderweireld       DF        Tottenham   30   33.0
# 10      Trent Alexander-Arnold       DF        Liverpool   20   38.0
# 11                     Alisson       GK        Liverpool   26   29.0
# 12                   Dele Alli    MF,FW        Tottenham   23   25.0
# ...

# %%
# save_pct = (shots_on_target_against - goals_against)/shots_on_target_against
# goals_prevented = PSxGSOT/no. of goals conceded

# %%
keeper = keeper_data.loc[:,['player','squad','age','minutes_gk','goals_against_gk','goals_against_per90_gk',
                            'shots_on_target_against','saves','save_pct','clean_sheets_pct','pens_allowed',
                            'psxg_gk','psnpxg_per_shot_on_target_against','psxg_net_gk']]
keeper = keeper[keeper['minutes_gk']>=1350]
keeper
# Out:
#                player            squad  age  minutes_gk  goals_against_gk  \
# 1             Alisson        Liverpool   26      2543.0              23.0
# 2   Kepa Arrizabalaga          Chelsea   24      2970.0              47.0
# 5     Martin Dúbravka    Newcastle Utd   30      3420.0              58.0
# 6             Ederson  Manchester City   25      3071.0              28.0
# 7    Łukasz Fabiański         West Ham   34      2117.0              34.0
# 9          Ben Foster          Watford   36      3420.0              64.0
# 10    Paulo Gazzaniga        Tottenham   27      1613.0              26.0
# 11       David de Gea   Manchester Utd   28      3420.0              36.0
# 12     Vicente Guaita   Crystal Palace   32      3150.0              42.0
# 14         Tom Heaton      Aston Villa   33      1794.0              35.0
# 15     Dean Henderson    Sheffield Utd   22      3240.0              33.0
# 17           Tim Krul     Norwich City   31      3240.0              68.0
# ...

# %% [raw]
# '''try:
#     keeper['save_pct'] = keeper.apply(lambda row: (row.shots_on_target_against - row.goals_against_gk)/row.shots_on_target_against,axis=1)
# except:
#     pass
# keeper'''

# %% [raw]
# '''def plot_players(df,factor):
#     plt.figure(figsize=(15,10))
#     m = sns.regplot(data=df,y=factor,x='minutes_gk',fit_reg=False,marker='o',color='cornflowerblue')
#
#     for line in range(0,df.shape[0]):
#         if factor=='goals_against_per90_gk':
#             if df[factor][line]>=0 and df[factor][line]<=2 and df['minutes_gk'][line]>=1200:
#                 m.text( df['minutes_gk'][line]-0.08,df[factor][line]+0.05, df.player[line], horizontalalignment='right', size='small', color='black', weight='semibold')
#         elif factor=='psxg_net_gk':
#             if df[factor][line]>=2.5 and df['minutes_gk'][line]>=1200:
#                 m.text( df['minutes_gk'][line]+0.5,df[factor][line]-0.4, df.player[line], horizontalalignment='right', size='small', color='black', weight='semibold')
#         else:
#             m.text( df['minutes_gk'][line]-0.01,df[factor][line]+0.01, df.player[line], horizontalalignment='right', size='small', color='black', weight='semibold')
#     '''

# %% [raw]
# cols = ['goals_against_per90_gk','save_pct','clean_sheets_pct','psnpxg_per_shot_on_target_against','psxg_net_gk']

# %% [raw]
# # plot_players(keeper,'goals_against_per90_gk')

# %% [raw]
# # plot_players(keeper,'save_pct')

# %% [raw]
# # plot_players(keeper,'psxg_net_gk')

# %%
def plot(df,xaxis,factor,mode):
    if mode=='bar':
        fig = px.bar(df, x=xaxis, y=factor)
        #fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
        fig.update_layout(xaxis={'categoryorder':'total descending'})
    elif mode=='scatter':
        h = df['player']
        if factor=='goals_assists_per90':
            fig = go.Figure()
            x = df[xaxis]
            y = df[factor]
            t = []
            for row in df.itertuples():
                if row.goals_assists_per90>=0.2:
                    t.append(row.player)
                else:
                    t.append(None)
            
            fig.add_trace(go.Scatter(
                            x=x,
                            y=y,
                            mode="markers+text",
                            text=t,
                            textposition="top center",
                            hovertext = h
                        ))
        elif factor=='npxg_xa_per90':
            fig = go.Figure()
            x = df[xaxis]
            y = df[factor]
            t = []
            for row in df.itertuples():
                if row.npxg_xa_per90>=0.40:
                    t.append(row.player)
                else:
                    t.append(None)
            
            fig.add_trace(go.Scatter(
                            x=x,
                            y=y,
                            mode="markers+text",
                            text=t,
                            textposition="top center",
                            hovertext = h
                        ))
        elif factor=='true_tackle_rate':
            fig = go.Figure()
            x = df[xaxis]
            y = df[factor]
            t = []
            for row in df.itertuples():
                if row.true_tackle_rate>=0.55:
                    t.append(row.player)
                else:
                    t.append(None)
            
            fig.add_trace(go.Scatter(
                            x=x,
                            y=y,
                            mode="markers+text",
                            text=t,
                            textposition="top center",
                            hovertext = h
                        ))
        elif factor=='tackle_perc':
            fig = go.Figure()
            x = df[xaxis]
            y = df[factor]
            t = []
            for row in df.itertuples():
                if row.tackle_perc>=0.50:
                    t.append(row.player)
                else:
                    t.append(None)
            
            fig.add_trace(go.Scatter(
                            x=x,
                            y=y,
                            mode="markers+text",
                            text=t,
                            textposition="top center",
                            hovertext = h
                        ))
        elif factor=='npxg_per90':
            fig = go.Figure()
            x = df[xaxis]
            y = df[factor]
            t = []
            for row in df.itertuples():
                if row.npxg_per90>=0.40:
                    t.append(row.player)
                else:
                    t.append(None)
            
            fig.add_trace(go.Scatter(
                            x=x,
                            y=y,
                            mode="markers+text",
                            text=t,
                            textposition="top center",
                            hovertext = h
                        ))
        elif factor=='goals_pens_per90':
            fig = go.Figure()
            x = df[xaxis]
            y = df[factor]
            t = []
            for row in df.itertuples():
                if row.goals_pens_per90>=0.40:
                    t.append(row.player)
                else:
                    t.append(None)
            
            fig.add_trace(go.Scatter(
                            x=x,
                            y=y,
                            mode="markers+text",
                            text=t,
                            textposition="top center",
                            hovertext = h
                        ))
        elif factor=='goals_assists_pens_per90':
            fig = go.Figure()
            x = df[xaxis]
            y = df[factor]
            t = []
            for row in df.itertuples():
                if row.goals_assists_pens_per90>=0.40:
                    t.append(row.player)
                else:
                    t.append(None)
            
            fig.add_trace(go.Scatter(
                            x=x,
                            y=y,
                            mode="markers+text",
                            text=t,
                            textposition="top center",
                            hovertext = h
                        ))
        else:
            fig = px.scatter(df, x=xaxis, y=factor, text='player')
            fig.update_traces(textposition='top center')
        fig.update_layout(
            title=f"{factor} vs {xaxis}",
            xaxis_title=xaxis,
            yaxis_title=factor,
        )
    # fig.write_image(f'defender/{factor}.png')
    fig.show()

# %%
plot(keeper,'player','psxg_net_gk','bar')
# Out:
# <div>
#
#
#             <div id="9f79c7a1-3493-4fb8-94e8-309eb7b2a7c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9f79c7a1-3493-4fb8-94e8-309eb7b2a7c7")) {
#                     Plotly.newPlot(
#                         '9f79c7a1-3493-4fb8-94e8-309eb7b2a7c7',
# ...

# %%
plot(keeper,'player','save_pct','bar')
# Out:
# <div>
#
#
#             <div id="bb9d981c-fe44-4efd-9dcb-371be6c830ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bb9d981c-fe44-4efd-9dcb-371be6c830ec")) {
#                     Plotly.newPlot(
#                         'bb9d981c-fe44-4efd-9dcb-371be6c830ec',
# ...

# %%
plot(keeper,'player','clean_sheets_pct','bar')
# Out:
# <div>
#
#
#             <div id="f99e8a42-d5a7-48b5-beb3-5ec286ddeeff" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f99e8a42-d5a7-48b5-beb3-5ec286ddeeff")) {
#                     Plotly.newPlot(
#                         'f99e8a42-d5a7-48b5-beb3-5ec286ddeeff',
# ...

# %%
plot(keeper,'player','goals_against_per90_gk','bar')
# Out:
# <div>
#
#
#             <div id="7ae8f061-d413-4123-9bff-7319e8230edf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7ae8f061-d413-4123-9bff-7319e8230edf")) {
#                     Plotly.newPlot(
#                         '7ae8f061-d413-4123-9bff-7319e8230edf',
# ...

# %% [raw]
# plot(keeper,'shots_on_target_against','bar')

# %% [raw]
# plot(keeper,'saves','bar')

# %%
defenders = out[out['position']=='DF']
defenders = defenders[defenders['minutes']>=1350]
defenders
# Out:
#                         player position            squad  age  games  \
# 0          Patrick van Aanholt       DF   Crystal Palace   28   29.0
# 1                   Max Aarons       DF     Norwich City   19   36.0
# 7                   Nathan Aké       DF      Bournemouth   24   29.0
# 9            Toby Alderweireld       DF        Tottenham   30   33.0
# 10      Trent Alexander-Arnold       DF        Liverpool   20   38.0
# 14               Marcos Alonso       DF          Chelsea   28   18.0
# 26                Serge Aurier       DF        Tottenham   26   33.0
# 28           César Azpilicueta       DF          Chelsea   29   36.0
# 32              George Baldock       DF    Sheffield Utd   26   38.0
# 33               Phil Bardsley       DF          Burnley   34   21.0
# 37                Chris Basham       DF    Sheffield Utd   31   38.0
# 40                Jan Bednarek       DF      Southampton   23   34.0
# 51               Ryan Bertrand       DF      Southampton   29   32.0
# ...

# %%
defenders.columns
# Out:
# Index(['player', 'position', 'squad', 'age', 'games', 'games_starts',
#        'minutes', 'goals', 'assists', 'cards_yellow', 'cards_red',
#        'goals_per90', 'assists_per90', 'goals_assists_per90',
#        'goals_pens_per90', 'goals_assists_pens_per90', 'xg', 'npxg', 'xa',
#        'xg_per90', 'xa_per90', 'xg_xa_per90', 'npxg_per90', 'npxg_xa_per90',
#        'tackles', 'tackles_won', 'dribble_tackles_pct', 'pressure_regain_pct',
#        'blocked_shots', 'blocked_shots_saves', 'fouls', 'cards_yellow',
#        'cards_red'],
#       dtype='object')

# %%
# tackling %
tackle_perc = defenders.apply(lambda row: (row['tackles_won']/row['tackles']) if row['tackles']!=0 else 0, axis=1)
defenders.insert(33,'tackle_perc',tackle_perc)

# %%
# true tackle win rate = total tackles/(total tackles + challenges lost(tackles lost)+fouls while tackling)
true_tackle_rate = defenders.apply(lambda row: row['tackles']/(row['tackles']+(row['tackles']-row['tackles_won'])+row['fouls']) if row['tackles']!=0 else 0,axis=1)
try:
    defenders.insert(34,'true_tackle_rate',true_tackle_rate)
except:
    pass
defenders.head()
# Out:
#                     player position           squad  age  games  games_starts  \
# 0      Patrick van Aanholt       DF  Crystal Palace   28   29.0          29.0
# 1               Max Aarons       DF    Norwich City   19   36.0          36.0
# 7               Nathan Aké       DF     Bournemouth   24   29.0          29.0
# 9        Toby Alderweireld       DF       Tottenham   30   33.0          33.0
# 10  Trent Alexander-Arnold       DF       Liverpool   20   38.0          35.0
#
#     minutes  goals  assists  cards_yellow  cards_red  goals_per90  \
# 0    2507.0    3.0      2.0           0.0        0.0         0.11
# 1    3240.0    0.0      1.0           7.0        0.0         0.00
# 7    2503.0    2.0      2.0           2.0        0.0         0.07
# 9    2957.0    2.0      2.0           7.0        0.0         0.06
# 10   3175.0    4.0     13.0           5.0        0.0         0.11
#
#     assists_per90  goals_assists_per90  goals_pens_per90  \
# ...

# %%
defenders[defenders['true_tackle_rate']==0]
# Out:
# Empty DataFrame
# Columns: [player, position, squad, age, games, games_starts, minutes, goals, assists, cards_yellow, cards_red, goals_per90, assists_per90, goals_assists_per90, goals_pens_per90, goals_assists_pens_per90, xg, npxg, xa, xg_per90, xa_per90, xg_xa_per90, npxg_per90, npxg_xa_per90, tackles, tackles_won, dribble_tackles_pct, pressure_regain_pct, blocked_shots, blocked_shots_saves, fouls, cards_yellow, cards_red, true_tackle_rate]
# Index: []

# %%
# goals_assists_per90, npxg_xa_per90, true_tackle_rate, pressure_regain_pct, dribble_tackle %, blocked_shot_saves

# %%
plot(defenders,'minutes','goals_assists_per90','scatter')
# Out:
# <div>
#
#
#             <div id="89e36a5a-6436-417d-842a-ed96729a8bf1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("89e36a5a-6436-417d-842a-ed96729a8bf1")) {
#                     Plotly.newPlot(
#                         '89e36a5a-6436-417d-842a-ed96729a8bf1',
# ...

# %%
plot(defenders,'minutes','npxg_xa_per90','scatter')
# Out:
# <div>
#
#
#             <div id="d1444ce7-ebed-4004-8dbe-d8ed53f1c90c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d1444ce7-ebed-4004-8dbe-d8ed53f1c90c")) {
#                     Plotly.newPlot(
#                         'd1444ce7-ebed-4004-8dbe-d8ed53f1c90c',
# ...

# %%
plot(defenders,'minutes','tackle_perc','scatter')
# Out:
# <div>
#
#
#             <div id="c81cb899-5f28-4b7a-9d9f-44aaece5f702" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c81cb899-5f28-4b7a-9d9f-44aaece5f702")) {
#                     Plotly.newPlot(
#                         'c81cb899-5f28-4b7a-9d9f-44aaece5f702',
# ...

# %%
plot(defenders,'minutes','true_tackle_rate','scatter')
# Out:
# <div>
#
#
#             <div id="5e450db2-59c2-4d94-8d89-022a258b9309" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5e450db2-59c2-4d94-8d89-022a258b9309")) {
#                     Plotly.newPlot(
#                         '5e450db2-59c2-4d94-8d89-022a258b9309',
# ...

# %%
defenders_abv = defenders[defenders['true_tackle_rate']>=0.5]
defenders_mins = defenders_abv[defenders_abv['minutes']>=1350]
defenders_mins.loc[:,['player','age','squad','minutes','true_tackle_rate']].sort_values('true_tackle_rate',ascending=False)

# %%
plot(defenders_mins,'minutes','true_tackle_rate','scatter')

# %%
fpl_data = pd.read_csv('cleaned_players.csv')
fpl_data.head()
# Out:
#        first_name           second_name  goals_scored  assists  total_points  \
# 0           Mesut                  Özil             1        3            53
# 1        Sokratis      Papastathopoulos             2        0            57
# 2           David  Luiz Moreira Marinho             2        1            94
# 3  Pierre-Emerick            Aubameyang            22        5           205
# 4          Cédric                Soares             1        1            61
#
#    minutes  goals_conceded  creativity  influence  threat  bonus  bps  \
# 0     1439              20       582.9      223.6   190.0      1  256
# 1     1696              25        36.8      436.2   110.0      5  305
# 2     2809              42       106.7      701.6   211.0     10  494
# 3     3136              44       479.6     1006.0  1369.0     37  807
# 4     1553              20       218.9      349.0   118.0      3  286
#
#    ict_index  clean_sheets  red_cards  yellow_cards  selected_by_percent  \
# ...

# %%
fpl_data.element_type.value_counts()
# Out:
# MID    211
# DEF    185
# FWD     64
# GK      51
# Name: element_type, dtype: int64

# %%
fpl_def = fpl_data[fpl_data['element_type']=='DEF'].loc[:,['first_name','second_name','now_cost','goals_scored','assists','total_points','minutes']].sort_values('total_points',ascending=False)
fpl_def
# Out:
#            first_name       second_name  now_cost  goals_scored  assists  \
# 274             Trent  Alexander-Arnold        75             4       15
# 270            Andrew         Robertson        70             2       12
# 265            Virgil          van Dijk        65             5        2
# 435              Matt           Doherty        60             4        8
# 84              James         Tarkowski        55             2        3
# 370              Enda           Stevens        55             2        4
# 374            George           Baldock        55             2        4
# 376              John              Egan        50             2        1
# 105             César       Azpilicueta        60             2        6
# 209             Jonny             Evans        55             1        2
# 64              Lewis              Dunk        50             3        3
# 328             Aaron       Wan-Bissaka        55             0        4
# ...

# %%
defenders[defenders['player']=='Enda Stevens']
# Out:
#            player position          squad  age  games  games_starts  minutes  \
# 446  Enda Stevens       DF  Sheffield Utd   29   38.0          38.0   3345.0
#
#      goals  assists  cards_yellow  cards_red  goals_per90  assists_per90  \
# 446    2.0      4.0           7.0        0.0         0.05           0.11
#
#      goals_assists_per90  goals_pens_per90  goals_assists_pens_per90   xg  \
# 446                 0.16              0.05                      0.16  1.2
#
#      npxg   xa  xg_per90  xa_per90  xg_xa_per90  npxg_per90  npxg_xa_per90  \
# 446   1.2  4.5      0.03      0.12         0.15        0.03           0.15
#
#      tackles  tackles_won  dribble_tackles_pct  pressure_regain_pct  \
# 446     76.0         43.0                 32.4                 26.6
#
#      blocked_shots  blocked_shots_saves  fouls  cards_yellow  cards_red  \
# 446            6.0                  0.0   39.0           7.0        0.0
#
#      tackle_perc  true_tackle_rate
# ...

# %%
defenders[defenders['player']=='George Baldock']
# Out:
#             player position          squad  age  games  games_starts  minutes  \
# 32  George Baldock       DF  Sheffield Utd   26   38.0          38.0   3420.0
#
#     goals  assists  cards_yellow  cards_red  goals_per90  assists_per90  \
# 32    2.0      3.0           7.0        0.0         0.05           0.08
#
#     goals_assists_per90  goals_pens_per90  goals_assists_pens_per90   xg  \
# 32                 0.13              0.05                      0.13  0.9
#
#     npxg   xa  xg_per90  xa_per90  xg_xa_per90  npxg_per90  npxg_xa_per90  \
# 32   0.9  2.5      0.02      0.07         0.09        0.02           0.09
#
#     tackles  tackles_won  dribble_tackles_pct  pressure_regain_pct  \
# 32     74.0         45.0                 52.1                 28.0
#
#     blocked_shots  blocked_shots_saves  fouls  cards_yellow  cards_red  \
# 32            5.0                  0.0   47.0           7.0        0.0
#
#     tackle_perc  true_tackle_rate
# 32     0.608108          0.493333

# %%
defenders[defenders['player']=='Virgil van Dijk']
# Out:
#               player position      squad  age  games  games_starts  minutes  \
# 111  Virgil van Dijk       DF  Liverpool   28   38.0          38.0   3420.0
#
#      goals  assists  cards_yellow  cards_red  goals_per90  assists_per90  \
# 111    5.0      1.0           1.0        0.0         0.13           0.03
#
#      goals_assists_per90  goals_pens_per90  goals_assists_pens_per90   xg  \
# 111                 0.16              0.13                      0.16  2.8
#
#      npxg   xa  xg_per90  xa_per90  xg_xa_per90  npxg_per90  npxg_xa_per90  \
# 111   2.8  1.3      0.07      0.03         0.11        0.07           0.11
#
#      tackles  tackles_won  dribble_tackles_pct  pressure_regain_pct  \
# 111     30.0         20.0                 40.0                 34.6
#
#      blocked_shots  blocked_shots_saves  fouls  cards_yellow  cards_red  \
# 111           16.0                  1.0   16.0           1.0        0.0
#
#      tackle_perc  true_tackle_rate
# ...

# %%
defenders[defenders['player']=='Lewis Dunk']
# Out:
#          player position     squad  age  games  games_starts  minutes  goals  \
# 124  Lewis Dunk       DF  Brighton   27   36.0          36.0   3230.0    3.0
#
#      assists  cards_yellow  cards_red  goals_per90  assists_per90  \
# 124      3.0           9.0        0.0         0.08           0.08
#
#      goals_assists_per90  goals_pens_per90  goals_assists_pens_per90   xg  \
# 124                 0.17              0.08                      0.17  4.2
#
#      npxg   xa  xg_per90  xa_per90  xg_xa_per90  npxg_per90  npxg_xa_per90  \
# 124   4.2  1.1      0.12      0.03         0.15        0.12           0.15
#
#      tackles  tackles_won  dribble_tackles_pct  pressure_regain_pct  \
# 124     43.0         28.0                 31.7                 43.1
#
#      blocked_shots  blocked_shots_saves  fouls  cards_yellow  cards_red  \
# 124           37.0                  3.0   19.0           9.0        0.0
#
#      tackle_perc  true_tackle_rate
# 124     0.651163          0.558442

# %%
defenders[defenders['player']=='Aaron Wan-Bissaka']
# Out:
#                 player position           squad  age  games  games_starts  \
# 491  Aaron Wan-Bissaka       DF  Manchester Utd   21   35.0          34.0
#
#      minutes  goals  assists  cards_yellow  cards_red  goals_per90  \
# 491   3070.0    0.0      4.0           8.0        0.0          0.0
#
#      assists_per90  goals_assists_per90  goals_pens_per90  \
# 491           0.12                 0.12               0.0
#
#      goals_assists_pens_per90   xg  npxg   xa  xg_per90  xa_per90  \
# 491                      0.12  0.9   0.9  3.0      0.03      0.09
#
#      xg_xa_per90  npxg_per90  npxg_xa_per90  tackles  tackles_won  \
# 491         0.12        0.03           0.12    138.0         65.0
#
#      dribble_tackles_pct  pressure_regain_pct  blocked_shots  \
# 491                 61.6                 28.8           14.0
#
#      blocked_shots_saves  fouls  cards_yellow  cards_red  tackle_perc  \
# 491                  0.0   22.0           8.0        0.0     0.471014
#
# ...

# %%
defenders[defenders['player']=='Chris Basham']
# Out:
#           player position          squad  age  games  games_starts  minutes  \
# 37  Chris Basham       DF  Sheffield Utd   31   38.0          38.0   3242.0
#
#     goals  assists  cards_yellow  cards_red  goals_per90  assists_per90  \
# 37    0.0      1.0           4.0        0.0          0.0           0.03
#
#     goals_assists_per90  goals_pens_per90  goals_assists_pens_per90   xg  \
# 37                 0.03               0.0                      0.03  0.5
#
#     npxg   xa  xg_per90  xa_per90  xg_xa_per90  npxg_per90  npxg_xa_per90  \
# 37   0.5  1.0      0.01      0.03         0.04        0.01           0.04
#
#     tackles  tackles_won  dribble_tackles_pct  pressure_regain_pct  \
# 37     84.0         50.0                 40.5                 32.5
#
#     blocked_shots  blocked_shots_saves  fouls  cards_yellow  cards_red  \
# 37           19.0                  1.0   26.0           4.0        0.0
#
#     tackle_perc  true_tackle_rate
# 37     0.595238          0.583333

# %%
defenders[defenders['player']=='Conor Coady']
# Out:
#          player position   squad  age  games  games_starts  minutes  goals  \
# 88  Conor Coady       DF  Wolves   26   38.0          38.0   3420.0    0.0
#
#     assists  cards_yellow  cards_red  goals_per90  assists_per90  \
# 88      0.0           5.0        0.0          0.0            0.0
#
#     goals_assists_per90  goals_pens_per90  goals_assists_pens_per90   xg  \
# 88                  0.0               0.0                       0.0  0.0
#
#     npxg   xa  xg_per90  xa_per90  xg_xa_per90  npxg_per90  npxg_xa_per90  \
# 88   0.0  0.7       0.0      0.02         0.02         0.0           0.02
#
#     tackles  tackles_won  dribble_tackles_pct  pressure_regain_pct  \
# 88     41.0         22.0                 50.0                 33.7
#
#     blocked_shots  blocked_shots_saves  fouls  cards_yellow  cards_red  \
# 88           18.0                  0.0   16.0           5.0        0.0
#
#     tackle_perc  true_tackle_rate
# 88     0.536585          0.539474

# %%
defenders[defenders['player']=='Reece James']
# Out:
#           player position    squad  age  games  games_starts  minutes  goals  \
# 214  Reece James       DF  Chelsea   19   24.0          16.0   1515.0    0.0
#
#      assists  cards_yellow  cards_red  goals_per90  assists_per90  \
# 214      2.0           1.0        0.0          0.0           0.12
#
#      goals_assists_per90  goals_pens_per90  goals_assists_pens_per90   xg  \
# 214                 0.12               0.0                      0.12  0.8
#
#      npxg   xa  xg_per90  xa_per90  xg_xa_per90  npxg_per90  npxg_xa_per90  \
# 214   0.8  3.4      0.05       0.2         0.24        0.05           0.24
#
#      tackles  tackles_won  dribble_tackles_pct  pressure_regain_pct  \
# 214     42.0         23.0                 45.2                 26.9
#
#      blocked_shots  blocked_shots_saves  fouls  cards_yellow  cards_red  \
# 214            8.0                  0.0   22.0           1.0        0.0
#
#      tackle_perc  true_tackle_rate
# 214     0.547619          0.506024

# %%
# goals_assists_pens_per90 is G+A-PK
pos = ['FW','MF','MF,FW','FW,MF']
attack = out.loc[out['position'].isin(pos)]
attack = attack.drop(columns=['tackles','tackles_won','dribble_tackles_pct','pressure_regain_pct','blocked_shots','blocked_shots_saves','fouls','cards_yellow','cards_red'])

# %%
attack = attack[attack['minutes']>=1350].sort_values('goals_assists_pens_per90',ascending=False)
attack.loc[:,['player','minutes','goals_assists_pens_per90']].head(26)
# Out:
#                         player  minutes  goals_assists_pens_per90
# 5                Sergio Agüero   1452.0                      1.05
# 104            Kevin De Bruyne   2791.0                      1.00
# 216              Gabriel Jesus   2030.0                      0.93
# 279               Riyad Mahrez   1944.0                      0.88
# 281                 Sadio Mané   2747.0                      0.82
# 407              Mohamed Salah   2876.0                      0.81
# 426                David Silva   1826.0                      0.79
# 286            Anthony Martial   2624.0                      0.79
# 194              Son Heung-min   2476.0                      0.76
# 208                 Danny Ings   2804.0                      0.74
# 2                Tammy Abraham   2215.0                      0.73
# 479                Jamie Vardy   3033.0                      0.71
# 445            Raheem Sterling   2651.0                      0.71
# ...

# %%
plot(attack,'minutes','goals_assists_pens_per90','scatter')
# Out:
# <div>
#
#
#             <div id="436bed5f-3228-428b-8435-5321fe12f62e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("436bed5f-3228-428b-8435-5321fe12f62e")) {
#                     Plotly.newPlot(
#                         '436bed5f-3228-428b-8435-5321fe12f62e',
# ...

# %%
attack = attack[attack['minutes']>=1350].sort_values('npxg_xa_per90',ascending=False)
attack.loc[:,['player','minutes','npxg_xa_per90']].head(26)
# Out:
#                         player  minutes  npxg_xa_per90
# 216              Gabriel Jesus   2030.0           0.96
# 5                Sergio Agüero   1452.0           0.86
# 104            Kevin De Bruyne   2791.0           0.79
# 445            Raheem Sterling   2651.0           0.76
# 407              Mohamed Salah   2876.0           0.75
# 279               Riyad Mahrez   1944.0           0.72
# 2                Tammy Abraham   2215.0           0.70
# 21             Michail Antonio   1768.0           0.69
# 281                 Sadio Mané   2747.0           0.67
# 479                Jamie Vardy   3033.0           0.63
# 141            Roberto Firmino   2988.0           0.59
# 375          Christian Pulisic   1722.0           0.59
# 208                 Danny Ings   2804.0           0.58
# 426                David Silva   1826.0           0.57
# 245        Alexandre Lacazette   1874.0           0.56
# 380            Marcus Rashford   2643.0           0.55
# ...

# %%
plot(attack,'minutes','npxg_xa_per90','scatter')
# Out:
# <div>
#
#
#             <div id="37fe1880-ffba-46b1-a9dc-ffbd2663ec8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("37fe1880-ffba-46b1-a9dc-ffbd2663ec8c")) {
#                     Plotly.newPlot(
#                         '37fe1880-ffba-46b1-a9dc-ffbd2663ec8c',
# ...

# %%
plot(attack,'minutes','goals_pens_per90','scatter')
# Out:
# <div>
#
#
#             <div id="02738f54-349e-40eb-adad-13257277bd00" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("02738f54-349e-40eb-adad-13257277bd00")) {
#                     Plotly.newPlot(
#                         '02738f54-349e-40eb-adad-13257277bd00',
# ...

# %%
plot(attack,'minutes','npxg_per90','scatter')
# Out:
# <div>
#
#
#             <div id="07ce26b9-9f17-4134-be8e-85e4cc1946d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("07ce26b9-9f17-4134-be8e-85e4cc1946d4")) {
#                     Plotly.newPlot(
#                         '07ce26b9-9f17-4134-be8e-85e4cc1946d4',
# ...

# %%
attack[attack['player']=='Jack Grealish']
# Out:
#             player position        squad  age  games  games_starts  minutes  \
# 174  Jack Grealish    FW,MF  Aston Villa   23   36.0          36.0   3233.0
#
#      goals  assists  goals_per90  assists_per90  goals_assists_per90  \
# 174    8.0      6.0         0.22           0.17                 0.39
#
#      goals_pens_per90  goals_assists_pens_per90   xg  npxg   xa  xg_per90  \
# 174              0.22                      0.39  6.4   5.6  6.9      0.18
#
#      xa_per90  xg_xa_per90  npxg_per90  npxg_xa_per90
# 174      0.19         0.37        0.16           0.35

# %%
attack[attack['player']=='Richarlison']
# Out:
#           player position    squad  age  games  games_starts  minutes  goals  \
# 384  Richarlison       FW  Everton   22   36.0          36.0   3070.0   13.0
#
#      assists  goals_per90  assists_per90  goals_assists_per90  \
# 384      3.0         0.38           0.09                 0.47
#
#      goals_pens_per90  goals_assists_pens_per90   xg  npxg   xa  xg_per90  \
# 384              0.38                      0.47  9.0   9.0  4.9      0.26
#
#      xa_per90  xg_xa_per90  npxg_per90  npxg_xa_per90
# 384      0.14         0.41        0.26           0.41

# %%
attack[attack['player']=='John Lundstram']
# Out:
#              player position          squad  age  games  games_starts  \
# 275  John Lundstram       MF  Sheffield Utd   25   34.0          26.0
#
#      minutes  goals  assists  goals_per90  assists_per90  goals_assists_per90  \
# 275   2458.0    5.0      3.0         0.18           0.11                 0.29
#
#      goals_pens_per90  goals_assists_pens_per90   xg  npxg   xa  xg_per90  \
# 275              0.18                      0.29  5.3   5.3  2.4      0.19
#
#      xa_per90  xg_xa_per90  npxg_per90  npxg_xa_per90
# 275      0.09         0.28        0.19           0.28

# %%
attack[attack['player']=='Dominic Calvert-Lewin']
# Out:
#                    player position    squad  age  games  games_starts  \
# 70  Dominic Calvert-Lewin       FW  Everton   22   36.0          30.0
#
#     minutes  goals  assists  goals_per90  assists_per90  goals_assists_per90  \
# 70   2626.0   13.0      1.0         0.45           0.03                 0.48
#
#     goals_pens_per90  goals_assists_pens_per90    xg  npxg   xa  xg_per90  \
# 70              0.45                      0.48  13.9  13.9  1.0      0.48
#
#     xa_per90  xg_xa_per90  npxg_per90  npxg_xa_per90
# 70      0.03         0.51        0.48           0.51

# %%
attack[attack['player']=='Wilfried Zaha']
# Out:
#             player position           squad  age  games  games_starts  \
# 517  Wilfried Zaha    MF,FW  Crystal Palace   26   38.0          37.0
#
#      minutes  goals  assists  goals_per90  assists_per90  goals_assists_per90  \
# 517   3280.0    4.0      3.0         0.11           0.08                 0.19
#
#      goals_pens_per90  goals_assists_pens_per90   xg  npxg   xa  xg_per90  \
# 517              0.11                      0.19  5.3   5.3  3.3      0.15
#
#      xa_per90  xg_xa_per90  npxg_per90  npxg_xa_per90
# 517      0.09         0.24        0.15           0.24

# %%
out[out['player']=='Che Adams']
# Out:
#       player position        squad  age  games  games_starts  minutes  goals  \
# 3  Che Adams       FW  Southampton   23   30.0          12.0   1111.0    4.0
#
#    assists  cards_yellow  cards_red  goals_per90  assists_per90  \
# 3      2.0           0.0        0.0         0.32           0.16
#
#    goals_assists_per90  goals_pens_per90  goals_assists_pens_per90   xg  npxg  \
# 3                 0.49              0.32                      0.49  4.2   4.2
#
#     xa  xg_per90  xa_per90  xg_xa_per90  npxg_per90  npxg_xa_per90  tackles  \
# 3  1.3      0.34       0.1         0.44        0.34           0.44      8.0
#
#    tackles_won  dribble_tackles_pct  pressure_regain_pct  blocked_shots  \
# 3          6.0                  0.0                 25.1            1.0
#
#    blocked_shots_saves  fouls  cards_yellow  cards_red
# 3                  0.0   17.0           0.0        0.0

# %%
fpl_pos = ['FWD','MID']
fpl_att = fpl_data[fpl_data['element_type'].isin(fpl_pos)].loc[:,['first_name','second_name','now_cost','total_points']].sort_values('total_points',ascending=False)
fpl_att['now_cost'] = fpl_att.apply(lambda row: row['now_cost']/10, axis=1)

# %%
fpl_data[fpl_data['first_name']=='Wilfried']
# Out:
#     first_name second_name  goals_scored  assists  total_points  minutes  \
# 147   Wilfried        Zaha             4        6           120     3279
#
#      goals_conceded  creativity  influence  threat  bonus  bps  ict_index  \
# 147              46       588.0      572.0  1103.0      4  337      226.4
#
#      clean_sheets  red_cards  yellow_cards  selected_by_percent  now_cost  \
# 147             9          0             5                  7.3        70
#
#     element_type
# 147          MID

# %%
fpl_att
# Out:
#            first_name               second_name  now_cost  total_points
# 287             Kevin                 De Bruyne      11.5           251
# 269           Mohamed                     Salah      12.0           233
# 266             Sadio                      Mané      12.0           221
# 214             Jamie                     Vardy      10.0           210
# 3      Pierre-Emerick                Aubameyang      12.0           205
# 291            Raheem                  Sterling      11.5           204
# 318           Anthony                   Martial       9.0           200
# 394             Danny                      Ings       8.5           198
# 492              Raúl                   Jiménez       8.5           194
# 321            Marcus                  Rashford       9.5           177
# 290             Riyad                    Mahrez       8.5           175
# 418         Heung-Min                       Son       9.0           169
# ...
